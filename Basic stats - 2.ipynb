# %% [markdown]
# # 💠Estimation And Confidence Intervals💠

# %%
import pandas as pd 
import numpy as np

# %%
Print_heads=[1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29]

# %% [markdown]
# ## 💠Build 99% Confidence Interval Using Sample Standard Deviation
#
# Assuming the sample is representative of the population, construct a 99% confidence interval for the mean number of characters printed before the print-head fails using the sample standard deviation. Explain the steps you take and the rationale behind using the t-distribution for this task.

# %%
Mean=np.mean(Print_heads)         #.....Mean of sample
Std=np.std(Print_heads)           #.....Standard deviation of sample
N=len(Print_heads)                #.....Number of elements in sample

print('Mean of sample = ',Mean)
print('Standard deviation of sample = ',Std)
print('Number of elements in sample = ',N)
# Out:
# Mean of sample =  1.2386666666666666
# Standard deviation of sample =  0.18661427836285438
# Number of elements in sample =  15

# %% [markdown]
# ![T-table.png](attachment:T-table.png)

# %%
# We have chosen the t-score as the population standard deviation is not known. 

Confidence_interval_percent=99
Degrees_freedom=N-1                #(Degrees_freedom=15-1=14)

t=2.977                            #The value of t obtained from t table corresponds to 99% and DF=14

# %%
Upper_CI=round(Mean + t*(Std/np.sqrt(N)),3)
Lower_CI=round(Mean - t*(Std/np.sqrt(N)),3)

print('The 99% confidence limits are ',f'({Lower_CI},{Upper_CI})')
# Out:
# The 99% confidence limits are  (1.095,1.382)

# %% [markdown]
# ### ▶The 99% confidence limits are  (1.095,1.382)

# %% [markdown]
# ## 💠Build 99% Confidence Interval Using Known Population Standard Deviation
# If it were known that the population standard deviation is 0.2 million characters, construct a 99% confidence interval for the mean number of characters printed before failure.

# %%
Mean=np.mean(Print_heads)         #.....Mean of sample
Population_Std=0.2                #.....Standard deviation of sample
N=len(Print_heads)                #.....Number of elements in sample

print('Mean of sample = ',Mean)
print('Standard deviation of sample = ',Population_Std)
print('Number of elements in sample = ',N)
# Out:
# Mean of sample =  1.2386666666666666
# Standard deviation of sample =  0.2
# Number of elements in sample =  15

# %% [markdown]
# ![8573955.webp](attachment:8573955.webp)

# %%
#Here we have use Z-score as population standard deviation was known

Confidence_interval_percent=99
Alpha=1-0.99                      #We have to find z for 0.995  which comes (2.5 + 0.07)
z=2.57

# %%
Upper_CI=round(Mean + z*(Population_Std/np.sqrt(N)),3)
Lower_CI=round(Mean - z*(Population_Std/np.sqrt(N)),3)

print('The 99% confidence limits are ',f'({Lower_CI},{Upper_CI})')
# Out:
# The 99% confidence limits are  (1.106,1.371)

# %% [markdown]
# ### ▶The 99% confidence limits are  (1.106,1.371)
