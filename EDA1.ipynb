# %% [markdown]
# # 💠EXPLORATORY DATA ANALYSIS ON A DATASET💠

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ##  💠Data Cleaning and Preparation:

# %%
data=pd.read_csv('Cardiotocographic.csv')
print('💠Shape of data ',data.shape)
data.head()
# Out:
# 💠Shape of data  (2126, 14)
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
data[data['LB'].isnull()]
# Out:
#       LB        AC        FM        UC        DL  DS  DP       ASTV      MSTV  \
# 50   NaN       NaN  0.000000  0.008086  0.000000 NaN NaN  29.000000  1.300000
# 116  NaN  0.038567  0.000000  0.006993  0.002331 NaN NaN  26.000000  4.300000
# 126  NaN       NaN  0.000000  0.004380  0.000000 NaN NaN  69.000000  0.300000
# 201  NaN       NaN  0.016393  0.000000  0.000000 NaN NaN  56.000000  0.500000
# 566  NaN       NaN  0.000000  0.004115  0.005487 NaN NaN  43.000000  2.500000
# 574  NaN       NaN  0.000000  0.002611  0.002611 NaN NaN  34.000000  4.900000
# 603  NaN       NaN  0.006519  0.001304  0.001304 NaN NaN  73.000000  0.700000
# 935  NaN       NaN  0.000000  0.005495  0.001374 NaN NaN  30.000000  1.251793
# 936  NaN       NaN  0.000000  0.007802  0.000000 NaN NaN  33.000000  1.000000
# 1013 NaN       NaN  0.000000  0.003861  0.000000 NaN NaN  34.000000  1.000000
# 1205 NaN       NaN -0.000129  0.006424  0.000000 NaN NaN  63.000000  0.500000
# ...

# %%
# Since all the 21 null values are in the same 21 records we can drop the null values 

data=data.dropna()
data.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
data.info()                                               #Identify and correct any inconsistencies in data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2105 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2105 non-null   float64
#  2   FM        2105 non-null   float64
#  3   UC        2105 non-null   float64
#  4   DL        2105 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2105 non-null   float64
#  8   MSTV      2105 non-null   float64
#  9   ALTV      2105 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 246.7 KB

# %%
plt.figure(figsize=(10,20))                        #Tendency[-1,0,1] and NSP[1,2,3] are categorical columns 
for y,x in enumerate(data.columns):
    v=data[x].value_counts()
    plt.subplot(7,3,y+1)
    plt.bar(v.index,height=v.values)
    plt.title(x)
plt.show()

# %%
data=data[data['NSP'].isin([1,2,3])]                            #Cleaning the Categorical columns
data=data[data['Tendency'].isin([1,0,-1])]
data=data.reset_index().drop('index',axis=1)
data.head()
# Out:
#            LB        AC   FM        UC        DL   DS        DP  ASTV  MSTV  \
# 0  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.000000  17.0   2.1
# 1  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.000000  16.0   2.1
# 2  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.000000  16.0   2.4
# 3  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.000000  16.0   2.4
# 4  134.000000  0.001116  0.0  0.010493  0.009444  0.0  0.002099  26.0   5.9
#
#    ALTV  MLTV  Width  Tendency  NSP
# 0   0.0  10.4  130.0       0.0  1.0
# 1   0.0  13.4  130.0       0.0  1.0
# 2   0.0  23.0  117.0       1.0  1.0
# 3   0.0  19.9  117.0       1.0  1.0
# 4   0.0   0.0  150.0       0.0  3.0

# %%
plt.subplot(1,2,1)
plt.bar(data['Tendency'].value_counts().index,height=data['Tendency'].value_counts().values)
plt.title('Tendency')
plt.subplot(1,2,2)
plt.bar(data['NSP'].value_counts().index,height=data['NSP'].value_counts().values)
plt.title('NSP')

plt.show()

# %% [markdown]
# ## 💠Outlier Treatment

# %%
before_shape=data.shape

# %%
Columns=['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
       'MLTV', 'Width']

plt.figure(figsize=(10,20))                         #Detect and treat outliers if necessary
for x,y in enumerate(Columns):
    plt.subplot(5,3,x+1)
    sns.boxplot(data[y])
    plt.title(y)
plt.show()

# %%
Q1=data[Columns].quantile(0.25)
Q3=data[Columns].quantile(0.75)
IQR=Q3-Q1

Data = data[~((data[Columns] < (Q1 - 1.5 * IQR)) | (data[Columns] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
print('Shape of data set before outlier treatment ',before_shape)
print('Shape of data set after outlier treatment ',Data.shape)
# Out:
# Shape of data set before outlier treatment  (1880, 14)
# Shape of data set after outlier treatment  (931, 14)

# %% [markdown]
# ### 🚩Note: Removing outliers removes 50% of data so outlier treatment is not recommendable

# %% [markdown]
# ## 💠Statistical Summary:

# %%
data.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  1880.000000  1880.000000  1880.000000  1880.000000  1880.000000
# mean    133.389428     0.003228     0.010320     0.004369     0.001891
# std      11.349363     0.004308     0.068865     0.003351     0.003248
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001777     0.000000
# 50%     133.000000     0.001654     0.000000     0.004470     0.000000
# 75%     141.000000     0.005638     0.002597     0.006579     0.003304
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  1880.000000  1880.000000  1880.000000  1880.000000  1880.000000
# mean      0.000002     0.000175    46.995315     1.369297    10.488888
# std       0.000147     0.000823    18.897437     1.186840    21.547175
# ...

# %%
Statistical_Summary = {
'Columns'                :list(Columns),
'Mean'                   :list(data[Columns].describe().loc['mean']),
'Median'                 :list(data[Columns].describe().loc['50%']),
'Standard_deviation'     :list(data[Columns].describe().loc['std']),
'interquartile range Q1' :list(Q1),
'interquartile range Q3' :list(Q3)   
}

Statistical_Summary=pd.DataFrame(Statistical_Summary).set_index('Columns')
Statistical_Summary
# Out:
#                Mean      Median  Standard_deviation  interquartile range Q1  \
# Columns
# LB       133.389428  133.000000           11.349363              126.000000
# AC         0.003228    0.001654            0.004308                0.000000
# FM         0.010320    0.000000            0.068865                0.000000
# UC         0.004369    0.004470            0.003351                0.001777
# DL         0.001891    0.000000            0.003248                0.000000
# DS         0.000002    0.000000            0.000147                0.000000
# DP         0.000175    0.000000            0.000823                0.000000
# ASTV      46.995315   49.000000           18.897437               32.000000
# MSTV       1.369297    1.200000            1.186840                0.700000
# ALTV      10.488888    0.000000           21.547175                0.000000
# MLTV       8.372105    7.450000            7.907628                4.600000
# ...

# %% [markdown]
# ## 	💠Data Visualization:

# %%
plt.figure(figsize=(10,30))

for x,y in enumerate(data.columns):
    plt.subplot(7,3,x+1)
    sns.histplot(data[y],kde=True)
    plt.title(y)
plt.show()

# %% [markdown]
# ### 🚩Note: In above representation 'Tendency' and 'NSP' are categorical columns

# %%
d=data.corr()

plt.figure(figsize=(10,5))
sns.heatmap(d,annot=True)
plt.show()

# %%
features=['AC','DP','ASTV','ALTV','UC','MLTV']      # These showes week to moderate relation with target[NSP]

plt.figure(figsize=(10,10))
for x,Y in enumerate(features):
    plt.subplot(3,2,x+1)
    sns.regplot(data,x='NSP',y=Y)
plt.show()

# %% [markdown]
# ## 💠Conclusion:
# ▶ As the temporal data is unavailable we cannot analyse any time based trend.
#
# ▶ Majority correlations among the variables are no-correlation to a weak-correlation in nature.
#
# ▶ Removal of outliers is not possible as it removes 20% to 50% data for Interquartile range of [0.1 to 0.9] to [0.25 to 0.75].
#
# ▶ Considering the week to moderate correlation here are some features for ML models:['AC','DP','ASTV','ALTV','UC','MLTV'].
#
# ▶ From the barchart observation it is clear that for ML model training data we have to use Oversampling methods or Undersampling methods to balance the categories for better accuracy of Model.
